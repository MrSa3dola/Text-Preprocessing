# %% [markdown]
# # Data:
# ### Extract HTML form URL

# %%
import requests

url = "https://www.searchenginejournal.com/introduction-to-python-seo-spreadsheets/342779/"

response = requests.get(url)
html_content = response.text

# %% [markdown]
# ### Extract text from HTML page

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_content, "html.parser")
text = soup.get_text()
# text = " ".join(
#     [p.get_text() for p in soup.find_all(["p", "h1", "h2", "h3", "h4", "h5", "h6"])]
# )

# %% [markdown]
# # Processing on Data:
# ## Convert to lower case

# %%
def convert_to_lower(text):
    copy_text = text
    return copy_text.lower()
text = convert_to_lower(text)

# %% [markdown]
# ## Removal of punctuations

# %%
import string
def remove_punctuations(text):
    copy_text = text
    punc = string.punctuation
    return copy_text.translate(str.maketrans('', '', punc))
text = remove_punctuations(text)

# %% [markdown]
# ## Removal of stopwords

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
STOPWORDS = stopwords.words('english')
def remove_stopwords(text):
    copy_text = text
    copy_text = " ".join([word for word in text.split() if word not in STOPWORDS])
    return copy_text
text = remove_stopwords(text)

# %% [markdown]
# ## Removal of special characters

# %%
import re
def remove_special_chars(text):
    copy_text = text
    copy_text = re.sub('[^a-zA-Z0-9]', " ", copy_text)
    copy_text = re.sub('\s+', ' ', copy_text)
    return copy_text
text = remove_special_chars(text)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Mariam M Saad\AppData\Local\Temp\ipykernel_7004\3721781939.py:5: SyntaxWarning: invalid escape sequence '\s'
#   copy_text = re.sub('\s+', ' ', copy_text)

# %% [markdown]
# ## Stemming

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def stem_words(text):
    copy_text = text
    return " ".join([ps.stem(word) for word in text.split()])
# text = stem_words(text)

# %%
stem_words("Going worried")
# Out:
# 'go worri'

# %% [markdown]
# ### Lemmatization

# %%
# import nltk
# # nltk.download('wordnet')
# # nltk.download('averaged_perceptron_tagger')

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

wordnet_map = {"N": wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}
def lemmatize_words(text):
    copy_text = text
    # find pos tags
    pos_text = pos_tag(copy_text.split())
    print(pos_text)
    # print(pos_text)
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])
text = lemmatize_words(text)
# Out:
# [('introduction', 'NN'), ('python', 'NN'), ('seo', 'NN'), ('pros', 'NNS'), ('using', 'VBG'), ('spreadsheets', 'NNS'), ('skip', 'JJ'), ('content', 'JJ'), ('latest', 'JJS'), ('news', 'NN'), ('seo', 'NN'), ('news', 'NN'), ('ppc', 'NN'), ('news', 'NN'), ('social', 'JJ'), ('media', 'NNS'), ('news', 'NN'), ('webinars', 'NNS'), ('podcast', 'VBP'), ('agencies', 'NNS'), ('career', 'VBP'), ('webinar', 'NN'), ('2024', 'CD'), ('google', 'NN'), ('serp', 'NN'), ('features', 'VBZ'), ('new', 'JJ'), ('strategies', 'NNS'), ('gain', 'VBP'), ('visibility', 'NN'), ('following', 'VBG'), ('presentation', 'NN'), ('tom', 'IN'), ('answering', 'VBG'), ('serp', 'JJ'), ('feature', 'JJ'), ('questions', 'NNS'), ('live', 'VBP'), ('qa', 'JJ'), ('won', 'VBD'), ('t', 'JJ'), ('want', 'JJ'), ('miss', 'NN'), ('come', 'VB'), ('prepared', 'JJ'), ('register', 'NN'), ('free', 'JJ'), ('seo', 'NN'), ('seo', 'NN'), ('seo', 'JJ'), ('news', 'NN'), ('seo', 'NN'), ('strategy', 'NN'), ('ask', 'VB'), ('seo', 'JJ'), ('enterprise', 'NN'), ('seo', 'NN'), ('google', 'NN'), ('algorithm', 'NN'), ('updates', 'VBZ'), ('international', 'JJ'), ('seo', 'NN'), ('link', 'NN'), ('building', 'VBG'), ('local', 'JJ'), ('seo', 'NN'), ('mobile', 'NN'), ('seo', 'NN'), ('onpage', 'NN'), ('seo', 'VBD'), ('technical', 'JJ'), ('seo', 'NN'), ('vertical', 'JJ'), ('seo', 'NN'), ('wordpress', 'NN'), ('seo', 'NN'), ('web', 'NN'), ('dev', 'NN'), ('seo', 'NN'), ('webinar', 'NN'), ('holistic', 'JJ'), ('website', 'JJ'), ('health', 'NN'), ('technical', 'JJ'), ('tips', 'NNS'), ('seo', 'JJ'), ('success', 'NN'), ('learn', 'NN'), ('tips', 'NNS'), ('improving', 'VBG'), ('websites', 'NNS'), ('technical', 'JJ'), ('health', 'NN'), ('including', 'VBG'), ('crawlability', 'NN'), ('indexability', 'NN'), ('site', 'NN'), ('speed', 'NN'), ('accessibility', 'NN'), ('register', 'VBP'), ('free', 'JJ'), ('paid', 'VBN'), ('media', 'NNS'), ('paid', 'VBN'), ('media', 'NNS'), ('paid', 'VBD'), ('media', 'NNS'), ('news', 'NN'), ('paid', 'VBN'), ('strategy', 'NN'), ('ask', 'NN'), ('ppc', 'NN'), ('expert', 'NN'), ('display', 'NN'), ('ads', 'NNS'), ('ppc', 'VBP'), ('programmatic', 'JJ'), ('social', 'JJ'), ('media', 'NNS'), ('advertising', 'VBG'), ('video', 'NN'), ('advertising', 'NN'), ('ebook', 'NN'), ('b2b', 'NN'), ('lead', 'JJ'), ('generation', 'NN'), ('create', 'NN'), ('content', 'NN'), ('converts', 'NNS'), ('strategy', 'NN'), ('guide', 'VBP'), ('first', 'JJ'), ('step', 'NN'), ('towards', 'NNS'), ('attracting', 'VBG'), ('highquality', 'NN'), ('leads', 'VBZ'), ('revolutionizing', 'VBG'), ('think', 'VB'), ('lead', 'JJ'), ('generation', 'NN'), ('download', 'NN'), ('content', 'NN'), ('content', 'NN'), ('content', 'JJ'), ('news', 'NN'), ('content', 'NN'), ('strategy', 'NN'), ('content', 'JJ'), ('creation', 'NN'), ('content', 'NN'), ('marketing', 'NN'), ('content', 'NN'), ('trends', 'NNS'), ('webinar', 'VBP'), ('content', 'JJ'), ('marketing', 'NN'), ('find', 'VBP'), ('true', 'JJ'), ('value', 'NN'), ('marketing', 'NN'), ('funnel', 'NN'), ('join', 'NN'), ('us', 'PRP'), ('explore', 'VBP'), ('comprehensive', 'JJ'), ('approach', 'NN'), ('measuring', 'VBG'), ('value', 'NN'), ('content', 'NN'), ('initiatives', 'NNS'), ('optimize', 'VBP'), ('resource', 'JJ'), ('allocation', 'NN'), ('maximum', 'JJ'), ('impact', 'NN'), ('register', 'NN'), ('free', 'JJ'), ('social', 'JJ'), ('social', 'JJ'), ('media', 'NNS'), ('social', 'JJ'), ('media', 'NNS'), ('news', 'NN'), ('social', 'JJ'), ('strategy', 'NN'), ('social', 'JJ'), ('media', 'NNS'), ('advertising', 'VBG'), ('facebook', 'NN'), ('instagram', 'NN'), ('linkedin', 'NN'), ('tiktok', 'NN'), ('twitter', 'NN'), ('youtube', 'NN'), ('webinar', 'NN'), ('content', 'NN'), ('marketing', 'NN'), ('find', 'VBP'), ('true', 'JJ'), ('value', 'NN'), ('marketing', 'NN'), ('funnel', 'NN'), ('join', 'NN'), ('us', 'PRP'), ('explore', 'VBP'), ('comprehensive', 'JJ'), ('approach', 'NN'), ('measuring', 'VBG'), ('value', 'NN'), ('content', 'NN'), ('initiatives', 'NNS'), ('optimize', 'VBP'), ('resource', 'JJ'), ('allocation', 'NN') ...

# %%
lemmatize_words("Going worried")
# Out:
# [('Going', 'VBG'), ('worried', 'VBD')]
# 'Going worry'

# %%
import spacy

def lemmatize_spacy(text):
    # Load the English language model
    nlp = spacy.load("en_core_web_sm")

    # Process the text with spaCy
    doc = nlp(text)

    # Lemmatize each token in the processed text
    lemmatized_text = " ".join([token.lemma_ for token in doc])
    return lemmatized_text
# Print the lemmatized text
lemmatize_spacy(text)
# Out:
# 'introduction python seo pro use spreadsheet skip content late news seo news ppc news social medium news webinar podcast agency career webinar 2024 google serp feature new strategy gain visibility follow presentation tom answer serp feature question live qa win t want miss come prepared register free seo seo seo news seo strategy ask seo enterprise seo google algorithm update international seo link build local seo mobile seo onpage seo technical seo vertical seo wordpress seo web dev seo webinar holistic website health technical tip seo success learn tip improve website technical health include crawlability indexability site speed accessibility register free pay medium pay medium pay medium news pay strategy ask ppc expert display ad ppc programmatic social medium advertise video advertising ebook b2b lead generation create content convert strategy guide first step towards attract highquality lead revolutionize think lead generation download content content content news content strategy content creation content marketing content trend webinar content marketing find true value marketing funnel join u explore comprehensive approach measure value content initiative optimize resource allocation maximum impact register free social social medium social medium news social strategy social medium advertise facebook instagram linkedin tiktok twitter youtube webinar content marketing find true value marketing funnel join u explore comprehensive approach measure value content initiative optimize resource allocation maximum impact register free digital digital marketing digital strategy affiliate marketing analytic data digital experience generative ai digital trend ecommerce lead generation wordpress webinar 2024 google serp feature new strategy gain visibility follow presentation tom answer serp feature question live qa win t want miss come prepared register free library webinars ebooks ebooks beginner guide seo core web vital guide google eat guide link build guide local seo guide onpage seo rank factor ebooks2 wordpress seo technical seo seo audit keyword research guide ppc guide facebook ad guide content marketing guide resource library ebooks webinars sej show podcast google algorithm update advertise advertising sej company subscribe contact career privacy policy sell personal info follow u google news linkedin facebook youtube twitter instagram reddit pinterest mastodon r advertise sell personal info advertisement sej seo introduction python seo pro use spreadsheet learn python basic study code john mueller recently share populate google sheet well also modify code add simple visualization vip contributor hamlet batista january 10 2020 18 min read vip contributor hamlet batista ceo ranksense bio follow 516 share 26k read 2019 far exceed expectation term python adoption within seo community start new year hear seo professional want join fun frustrate initial learn curve decide write introductory piece goal get people involve contribute seo work involve work spreadsheet redo manually work multiple brand repeat analysis time implement workflow python trivially reproduce work even automate whole workflow go learn python basic study code john mueller recently share twitter populate google sheet modify code add simple visualization use wikipedia api pull field curious spreadsheet httpstcoosbeneubgt colab code httpstcostab1vk8n4 john johnmu january 3 2020 set python environment similar work excel google sheet two primary option work python install run python local computer run cloud use google colab jupyter notebook let s review one work python local computer typically choose work mac software win t run cloud example need automate web browser need download three software package anaconda visual studio code python bind code go httpswwwanacondacomdistribution download install python 37 operating system anaconda include python library need datum analysis take complete do search anaconda navigator launch click launch jupyterlab open new tab b ...

# %%
lemmatize_spacy("Going")
# Out:
# 'go'

# %% [markdown]
# ## Removal of URLs

# %%
def remove_url(text):
    copy_text = text
    return re.sub(r'https?://\S+|www\.\S+', '', copy_text)
text = remove_url(text)

# %% [markdown]
# ## Removal of HTML tags

# %%
def remove_html_tags(text):
    copy_text = text
    return re.sub(r'<.*?>', '', copy_text)
text = remove_html_tags(text)

# %%
def remove_digits(text):
    copy_text = text
    return ''.join([i for i in copy_text if not i.isdigit()])
text = remove_digits(text)

# %% [markdown]
# # Unique Words

# %%
print(len(text.split()))
# Out:
# 2393

# %%
all_unique = set(text.split())
print(len(all_unique))
# Out:
# 806

# %%
all_unique
# Out:
# {'able',
#  'access',
#  'accessibility',
#  'action',
#  'actionqueryformatjsonpropinfotitlesavengersaendgame',
#  'actually',
#  'ad',
#  'adapt',
#  'add',
#  'adoption',
#  'advertise',
#  'advertisement',
#  'advertising',
#  'affiliate',
#  'agency',
#  'aggregation',
#  'agile',
#  'ai',
#  'algorithm',
#  'algorithmic',
#  'algorithms',
#  'alias',
#  'allocation',
#  'allow',
#  'alonso',
#  'alpha',
#  'already',
#  'also',
#  'always',
#  'anaconda',
#  'analysis',
#  'analytics',
#  'analyze',
#  'another',
#  'answer',
#  'anything',
#  'api',
#  'app',
#  'apparently',
#  'approach',
#  'arithmetic',
#  'article',
#  'ask',
#  'atoi',
#  'attract',
#  'audit',
#  'auth',
#  'authauthenticateuser',
#  'authenticate',
#  'authentication',
#  'author',
#  'authority',
#  'automate',
#  'automatically',
#  'available',
#  'avenger',
#  'avoid',
#  'awesome',
#  'back',
#  'bar',
#  'basic',
#  'batchcomplete',
#  'batista',
#  'bb',
#  'begin',
#  'beginner',
#  'behavior',
#  'best',
#  'big',
#  'binding',
#  'bio',
#  'bit',
#  'blindly',
#  'block',
#  'boolean',
#  'booleans',
#  'brand',
#  'break',
#  'brings',
#  'browser',
#  'build',
#  'building',
#  'builtin',
#  'bunch',
#  'business',
#  'c',
#  'calculate',
#  'call',
#  'cant',
#  'care',
#  'career',
#  'carefully',
#  'case',
#  'category',
#  'celebrity',
#  'ceo',
#  'chart',
#  'check',
#  'choice',
#  'choose',
#  'chrome',
#  'clarify',
#  'click',
#  'cloud',
#  'code',
#  'colab',
#  'collection',
#  'column',
#  'columnnr',
#  'columns',
#  'combination',
#  'combine',
#  'come',
#  'command',
#  'commandline',
#  'commandshiftp',
#  'commas',
#  'comment',
#  'common',
#  'community',
#  'company',
#  'compare',
#  'complete',
#  'complex',
#  'complicate',
#  'comprehensive',
#  'computer',
#  'concatenate',
#  'confuse',
#  'conquer',
#  'consider',
#  'contact',
#  'contain',
#  'content',
#  'contentmodel',
#  'context',
#  'contribute',
#  'contributor',
#  'control',
#  'conversion',
#  'convert',
#  'cool',
#  'copy',
#  'copypasting',
#  'copyright',
#  'core',
#  'corresponding',
#  'could',
#  'couple',
#  'cover',
#  'crawlability',
#  'create',
#  'creation',
#  'credit',
#  'curious',
#  'curl',
#  'curve',
#  'custom',
#  'd',
#  'daily',
#  'data',
#  'dataframe',
#  'dataframeiterrows',
#  'day',
#  'de',
#  'december',
#  'decide',
#  'def',
#  'default',
#  'define',
#  'definition',
#  'demand',
#  'description',
#  'desktop',
#  'detail',
#  'detailed',
#  'dev',
#  'development',
#  'df',
#  'dfcolumnsgetlocfieldname',
#  'dfgroupbywikidatainstanceaggviewsmobile',
#  'dfiterrows',
#  'dfviewsdesktop',
#  'dfviewsdesktopapplyatoi',
#  'dfviewsmobile',
#  'dfviewsmobileapplyatoi',
#  'dice',
#  'dictionaries',
#  'dictionary',
#  'dictkeys',
#  'difference',
#  'digital',
#  'directly',
#  'display',
#  'do',
#  'document',
#  'documentation',
#  'doesnt',
#  'don',
#  'dont',
#  'dose',
#  'download',
#  'drilling',
#  'drive',
#  'dtype',
#  'dynamically',
#  'easy',
#  'eat',
#  'ebook',
#  'ebooks',
#  'ecommerce',
#  'effort',
#  'element',
#  'else',
#  'empty',
#  'en',
#  'end',
#  'endgame',
#  'engine',
#  'enterprise',
#  'entertainment',
#  'entrepreneurs',
#  'environment',
#  'equivalent',
#  'error',
#  'even',
#  'every',
#  'everything',
#  'example',
#  'exceeded',
#  'excel',
#  'except',
#  'excite',
#  'execute',
#  'exist',
#  'expect',
#  'expectation',
#  'experience',
#  'expert',
#  'expertise',
#  'explicit',
#  'exploration',
#  'explore',
#  'extension',
#  'extoutlinks',
#  'extract',
#  'facebook',
#  'factor',
#  'false',
#  'familiar',
#  'far',
#  'faster',
#  'feature',
#  'feedback',
#  'field',
#  'fieldname',
#  'figure',
#  'file',
#  'fill',
#  'film',
#  'filter',
#  'final',
#  'finally',
#  'find',
#  'first',
#  'flag',
#  'flow',
#  'focus',
#  'follow',
#  'forceupdate',
#  'forceupdatefalse',
#  'forceupdatetrue',
#  'form',
#  'format',
#  'forth',
#  'founder',
#  'frame',
#  'free',
#  'friend',
#  'frustrate',
#  'full',
#  'fun',
#  'function',
#  'functionality',
#  'functiontocall',
#  'functiontocallgetpageid',
#  'functiontocallparametername',
#  'functiontocallrowparametername',
#  'funnel',
#  'gain',
#  'game',
#  'gc',
#  'gcopenspreadsheetnamesheet',
#  'gcopenwikipediaviewssheet',
#  'generally',
#  'generate',
#  'generation',
#  'generative',
#  'generator',
#  'get',
#  'getdescription',
#  'getdescriptionpageid',
#  'getpageid',
#  'getpageidtitle',
#  'give',
#  'go',
#  'goal',
#  'good',
#  'google',
#  'googlecolab',
#  'googlecredentials',
#  'grab',
#  'grow',
#  'gspread',
#  'gspreadauthorizegooglecredentialsgetapplicationdefault',
#  'guide',
#  'hamlet',
#  'hardcoded',
#  'health',
#  'hear',
#  'helper',
#  'hera',
#  'highlevel',
#  'highquality',
#  'hold',
#  'holistic',
#  'homework',
#  'however',
#  'httpscodevisualstudiocomdownload',
#  'httpscolabresearchgooglecom',
#  'httpsenwikipediaorgwapiphp',
#  'httpsenwikipediaorgwapiphpactionqueryformatjsonpropinfotitlesavengersaendgame',
#  'httpsenwikipediaorgwapiphpactionqueryformatjsonproppagetermspageids',
#  'httpsenwikipediaorgwikic',
#  'httpsstackoverflowcomquestionsconvertnumberstringswithcommasinpandasdataframetofloat',
#  'httpstcoosbeneubgt',
#  'httpstcostabvkn',
#  'httpswwwanacondacomdistribution',
#  'icon',
#  'id',
#  'idea',
#  'identifier',
#  'ignore',
#  'image',
#  'impact',
#  'implement',
#  'import',
#  'important',
#  'improve',
#  'in',
#  'include',
#  'index',
#  'indexability',
#  'info',
#  'information',
#  'initial',
#  'initially',
#  'initiative',
#  'input',
#  'instagram',
#  'install',
#  'installation',
#  'integer',
#  'intention',
#  'interest',
#  'international',
#  'intlistresponsejsonquerypageskeys',
#  'introduction',
#  'introductory',
#  'involve',
#  'item',
#  'iterate',
#  'iteration',
#  'iterator',
#  'iterators',
#  'iterrows',
#  'january',
#  'javascript',
#  'job',
#  'john',
#  'johnmu',
#  'join',
#  'journal',
#  'jq',
#  'json',
#  'jupyter',
#  'jupyterlab',
#  'k',
#  'keep',
#  'key',
#  'keyvalue',
#  'keyword',
#  'keywords',
#  'kind',
#  'know',
#  'knowhow',
#  'la',
#  'label',
#  'language',
#  'last',
#  'lastrevid',
#  'late',
#  'launch',
#  'lead',
#  'learn',
#  'learned',
#  'leave',
#  'length',
#  'less',
#  'let',
#  'library',
#  'like',
#  'limitation',
#  'line',
#  'link',
#  'linkedin',
#  'list',
#  'listresponsejsonquerypageskeys',
#  'little',
#  'live',
#  'local',
#  'locale',
#  'localesetlocalelocalelcnumeric',
#  'locally',
#  'logical',
#  'look',
#  'lookup',
#  'loop',
#  'loops',
#  'lot',
#  'ltr',
#  'mac',
#  'main',
#  'make',
#  'manipulate',
#  'manipulation',
#  'manually',
#  'manufacturer',
#  'map',
#  'mark',
#  'marketer',
#  'marketing',
#  'marvel',
#  'mastodon',
#  'matter',
#  'maximum',
#  'measure',
#  'medical',
#  'medium',
#  'meet',
#  'memory',
#  'mention',
#  'might',
#  'min',
#  'mind',
#  'minute',
#  'miss',
#  'mobile',
#  'mobilehttpstcolvedymnpb',
#  'modify',
#  'module',
#  'mostly',
#  'mueller',
#  'multiple',
#  'name',
#  'names',
#  'navigator',
#  'necessary',
#  'need',
#  'nest',
#  'new',
#  'news',
#  'newsletter',
#  'next',
#  'note',
#  'notebook',
#  'notebooks',
#  'notice',
#  'npsum',
#  'ns',
#  'number',
#  'oauth',
#  'oauthclientclient',
#  'object',
#  'one',
#  'online',
#  'onpage',
#  'open',
#  'operating',
#  'operation',
#  'operator',
#  'opportunity',
#  'optimize',
#  'option',
#  'optional',
#  'others',
#  'output',
#  'overall',
#  'overkill',
#  'overview',
#  'package',
#  'page',
#  'pageid',
#  'pagelanguage',
#  'pagelanguagedir',
#  'pagelanguagehtmlcode',
#  'pair',
#  'panda',
#  'pandas',
#  'parameter',
#  'parametername',
#  'parse',
#  'part',
#  'partially',
#  'partmobile',
#  'pass',
#  'passing',
#  'paste',
#  'pay',
#  'pd',
#  'pddataframefromrecordsworksheetrows',
#  'pdtonumericdfviewsmobile',
#  'people',
#  'perfect',
#  'perform',
#  'personal',
#  'personally',
#  'piece',
#  'pinterest',
#  'pip',
#  'pivot',
#  'place',
#  'platform',
#  'play',
#  'please',
#  'plot',
#  'podcast',
#  'policy',
#  'pomeranians',
#  'popular',
#  'populate',
#  'populates',
#  'position',
#  'powerful',
#  'ppc',
#  'practical',
#  'practice',
#  'practitioner',
#  'precise',
#  'prefer',
#  'prefilled',
#  'prepared',
#  'prepending',
#  'presentation',
#  'previous',
#  'primary',
#  'print',
#  'printvariblename',
#  'privacy',
#  'pro',
#  'process',
#  'produce',
#  'professional',
#  'program',
#  'programmatic',
#  'programmer',
#  'progressbar',
#  'project',
#  'prop',
#  'prototype',
#  'provide',
#  'publish',
#  'pull',
#  'put',
#  'puzzle',
#  'python',
#  'q',
#  'qa',
#  'query',
#  'question',
#  'r',
#  'ranking',
#  'ranksense',
#  'read',
#  'readonly',
#  'recalculate',
#  'receive',
#  'recently',
#  'recommend',
#  'reddit',
#  'redo',
#  'reference',
#  'register',
#  'relevant',
#  'render',
#  'repeat',
#  'represent',
#  'reproduce',
#  'request',
#  'requestsget',
#  'requestsgethttpsenwikipediaorgwapiphpactionqueryformatjsonpropinfotitlesavengersaendgame',
#  'requestsgeturl',
#  'require',
#  'rescue',
#  'research',
#  'reserve',
#  'resource',
#  'response',
#  'responsejsonquery',
#  'responsejsonquerypages',
#  'responsejsonquerypageskeys',
#  'result',
#  'retailer',
#  'retrieve',
#  'return',
#  'review',
#  'revolutionize',
#  'right',
#  'row',
#  'rowfieldname',
#  'rowpageid',
#  'rs',
#  'rsterms',
#  'rstermsdescription',
#  'rule',
#  'run',
#  's',
#  'sar',
#  'saralonsode',
#  'save',
#  'saw',
#  'screenshot',
#  'script',
#  'sdsdsds',
#  'search',
#  'section',
#  'see',
#  'sej',
#  'select',
#  'sell',
#  'send',
#  'sensible',
#  'seo',
#  'seos',
#  'separate',
#  'serp',
#  'session',
#  'set',
#  'several',
#  'share',
#  'sheet',
#  'shell',
#  'shop',
#  'show',
#  'side',
#  'sign',
#  'similar',
#  'simple',
#  'site',
#  'skip',
#  'slice',
#  'small',
#  'snippet',
#  'social',
#  'software',
#  'solid',
#  'something',
#  'speed',
#  'spreadsheet',
#  'stackoverflow',
#  'standard',
#  'start',
#  'statement',
#  'step',
#  'still',
#  'store',
#  'story',
#  'strategy',
#  'string',
#  'structure',
#  'studio',
#  'study',
#  'subscribe',
#  'subsequent',
#  'success',
#  'successful',
#  'suggest',
#  'superhero',
#  'support',
#  'sure',
#  'symbol',
#  'system',
#  't',
#  'tab',
#  'table',
#  'take',
#  'technical',
#  'term',
#  'textual',
#  'thing',
#  'think',
#  'thirdparty',
#  'three',
#  'tiktok',
#  'time',
#  'timely',
#  'tip',
#  'title',
#  'together',
#  'tom',
#  'tool',
#  'top',
#  'topic',
#  'topical',
#  'totalsdf',
#  'totalsdfheadplotkindbar',
#  'touch',
#  'towards',
#  'transformation',
#  'translate',
#  'trend',
#  'trivially',
#  'true',
#  'try',
#  'tutorial',
#  'twitter',
#  'two',
#  'type',
#  'typical',
#  'typically',
#  'typing',
#  'tz',
#  'u',
#  'unable',
#  'uncover',
#  'understand',
#  'understanding',
#  'unix',
#  'unless',
#  'update',
#  'updated',
#  'updatespreadsheetrows',
#  'updatespreadsheetrowsfieldname',
#  'updatespreadsheetrowspageid',
#  'upgrade',
#  'url',
#  'urlencode',
#  'urllibparse',
#  'urllibparseurlencode',
#  'urllibparseurlencodeaction',
#  'urllibparseurlencodeq',
#  'use',
#  'useful',
#  'v',
#  'valuable',
#  'value',
#  'valueerror',
#  'variable',
#  've',
#  'vertical',
#  'via',
#  'video',
#  'view',
#  'viewsdesktop',
#  'viewsdesktopapplymapatoi',
#  'viewsmobile',
#  'vip',
#  'visibility',
#  'visual',
#  'visualization',
#  'visualize',
#  'vitals',
#  'vsc',
#  'want',
#  'way',
#  'we',
#  'web',
#  'webinar',
#  'webinars',
#  'website',
#  'well',
#  'whole',
#  'wikidataid',
#  'wikidatainstance',
#  'wikiinlinks',
#  'wikioutlinks',
#  'wikipedia',
#  'wikitext',
#  'win',
#  'within',
#  'without',
#  'wordpress',
#  'work',
#  'workflow',
#  'worksheet',
#  'worksheetgetallvalues',
#  'worksheetrows',
#  'worksheetupdatecell',
#  'worksheetupdatecellindex',
#  'world',
#  'would',
#  'write',
#  'xfaddbf',
#  'year',
#  'you',
#  'youtube'}

# %%
all  = text.split()
print(all)
g = []
for i in range(len(all)):
    if len(all[i]) < 3:
        g.append(all[i])
    
final_text = " ".join(g)
final_text
# Out:
# ['introduction', 'python', 'seo', 'pro', 'use', 'spreadsheet', 'skip', 'content', 'late', 'news', 'seo', 'news', 'ppc', 'news', 'social', 'medium', 'news', 'webinars', 'podcast', 'agency', 'career', 'webinar', 'google', 'serp', 'feature', 'new', 'strategy', 'gain', 'visibility', 'follow', 'presentation', 'tom', 'answer', 'serp', 'feature', 'question', 'live', 'qa', 'win', 't', 'want', 'miss', 'come', 'prepared', 'register', 'free', 'seo', 'seo', 'seo', 'news', 'seo', 'strategy', 'ask', 'seo', 'enterprise', 'seo', 'google', 'algorithm', 'update', 'international', 'seo', 'link', 'build', 'local', 'seo', 'mobile', 'seo', 'onpage', 'seo', 'technical', 'seo', 'vertical', 'seo', 'wordpress', 'seo', 'web', 'dev', 'seo', 'webinar', 'holistic', 'website', 'health', 'technical', 'tip', 'seo', 'success', 'learn', 'tip', 'improve', 'website', 'technical', 'health', 'include', 'crawlability', 'indexability', 'site', 'speed', 'accessibility', 'register', 'free', 'pay', 'medium', 'pay', 'medium', 'pay', 'medium', 'news', 'pay', 'strategy', 'ask', 'ppc', 'expert', 'display', 'ad', 'ppc', 'programmatic', 'social', 'medium', 'advertise', 'video', 'advertising', 'ebook', 'bb', 'lead', 'generation', 'create', 'content', 'convert', 'strategy', 'guide', 'first', 'step', 'towards', 'attract', 'highquality', 'lead', 'revolutionize', 'think', 'lead', 'generation', 'download', 'content', 'content', 'content', 'news', 'content', 'strategy', 'content', 'creation', 'content', 'marketing', 'content', 'trend', 'webinar', 'content', 'marketing', 'find', 'true', 'value', 'marketing', 'funnel', 'join', 'u', 'explore', 'comprehensive', 'approach', 'measure', 'value', 'content', 'initiative', 'optimize', 'resource', 'allocation', 'maximum', 'impact', 'register', 'free', 'social', 'social', 'medium', 'social', 'medium', 'news', 'social', 'strategy', 'social', 'medium', 'advertise', 'facebook', 'instagram', 'linkedin', 'tiktok', 'twitter', 'youtube', 'webinar', 'content', 'marketing', 'find', 'true', 'value', 'marketing', 'funnel', 'join', 'u', 'explore', 'comprehensive', 'approach', 'measure', 'value', 'content', 'initiative', 'optimize', 'resource', 'allocation', 'maximum', 'impact', 'register', 'free', 'digital', 'digital', 'marketing', 'digital', 'strategy', 'affiliate', 'marketing', 'analytics', 'data', 'digital', 'experience', 'generative', 'ai', 'digital', 'trend', 'ecommerce', 'lead', 'generation', 'wordpress', 'webinar', 'google', 'serp', 'feature', 'new', 'strategy', 'gain', 'visibility', 'follow', 'presentation', 'tom', 'answer', 'serp', 'feature', 'question', 'live', 'qa', 'win', 't', 'want', 'miss', 'come', 'prepared', 'register', 'free', 'library', 'webinars', 'ebooks', 'ebooks', 'beginner', 'guide', 'seo', 'core', 'web', 'vitals', 'guide', 'google', 'eat', 'guide', 'link', 'build', 'guide', 'local', 'seo', 'guide', 'onpage', 'seo', 'ranking', 'factor', 'ebooks', 'wordpress', 'seo', 'technical', 'seo', 'seo', 'audit', 'keyword', 'research', 'guide', 'ppc', 'guide', 'facebook', 'ad', 'guide', 'content', 'marketing', 'guide', 'resource', 'library', 'ebooks', 'webinars', 'sej', 'show', 'podcast', 'google', 'algorithm', 'update', 'advertise', 'advertising', 'sej', 'company', 'subscribe', 'contact', 'career', 'privacy', 'policy', 'sell', 'personal', 'info', 'follow', 'u', 'google', 'news', 'linkedin', 'facebook', 'youtube', 'twitter', 'instagram', 'reddit', 'pinterest', 'mastodon', 'r', 'advertise', 'sell', 'personal', 'info', 'advertisement', 'sej', 'seo', 'introduction', 'python', 'seo', 'pro', 'use', 'spreadsheet', 'learn', 'python', 'basic', 'study', 'code', 'john', 'mueller', 'recently', 'share', 'populates', 'google', 'sheet', 'well', 'also', 'modify', 'code', 'add', 'simple', 'visualization', 'vip', 'contributor', 'hamlet', 'batista', 'january', 'min', 'read', 'vip', 'contributor', 'hamlet', 'batista', 'ceo', 'ranksense', 'bio', 'follow', 'share', 'k', 'read', 'far', 'exceeded', 'expectation', 'term', 'python', 'adoption', 'within', 'seo', 'communi ...
# 'qa t ad bb u u ai qa t ad u r k go s t go do go go in go s s v s s s id s id q q d q q s q u ns en en tz s ns en en tz ns en en tz jq we ve u s s ns rs rs r s go s q t c de la id df pd df s gc s s u ai'
